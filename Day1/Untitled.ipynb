# %%
import pandas as pd
pd.set_option("display.max_rows",1000)
pd.set_option("display.max_columns",20)
pd.set_option('precision',7)
pd.set_option('large_repr','truncate')

# %%
data= pd.DataFrame({'group' : ['a', 'a', 'b', 'b', 'c', 'c'], 'ounces' : [4, 10, 3, 56, 7, 8]})

# %%
data
# Out:
#   group  ounces
# 0     a       4
# 1     a      10
# 2     b       3
# 3     b      56
# 4     c       7
# 5     c       8

# %%
data:describe
# Out:
#   File "<ipython-input-12-042916295db9>", line 1
#     data:describe
#         ^
# SyntaxError: invalid syntax

# %%
data.describe()
# Out:
#            ounces
# count   6.0000000
# mean   14.6666667
# std    20.4124145
# min     3.0000000
# 25%     4.7500000
# 50%     7.5000000
# 75%     9.5000000
# max    56.0000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
# group     6 non-null object
# ounces    6 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 168.0+ bytes

# %%
data.sort_values(by=['group','ounces'], ascending=[False,True], implace=[True])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8127fa9877b7> in <module>()
# ----> 1 data.sort_values(by=['group','ounces'], ascending=[False,True], implace=[True])
#
# TypeError: sort_values() got an unexpected keyword argument 'implace'

# %%
|
# Out:
#   File "<ipython-input-16-6f719179e65e>", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
data.sort_values(by=['group','ounces'], ascending=[False,True], implace=[True])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8127fa9877b7> in <module>()
# ----> 1 data.sort_values(by=['group','ounces'], ascending=[False,True], implace=[True])
#
# TypeError: sort_values() got an unexpected keyword argument 'implace'

# %%
data.sort_values(by=['group','ounces'], ascending=[False,True], inplace=[True])

# %%
print(data)
# Out:
#   group  ounces
# 4     c       7
# 5     c       8
# 2     b       3
# 3     b      56
# 0     a       4
# 1     a      10

# %%
data= pd.DataFrame({'group' : ['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c'], 'ounces' : [4, 10, 4, 3, 56,56, 7, 7, 7]})
data
# Out:
#   group  ounces
# 0     a       4
# 1     a      10
# 2     a       4
# 3     b       3
# 4     b      56
# 5     b      56
# 6     c       7
# 7     c       7
# 8     c       7

# %%
data.drop_duplicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b35456f37d42> in <module>()
# ----> 1 data.drop_duplicate()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplicate'

# %%
data.drop_duplicates()
# Out:
#   group  ounces
# 0     a       4
# 1     a      10
# 3     b       3
# 4     b      56
# 6     c       7

# %%
data.drop_duplicates(subset="group")
# Out:
#   group  ounces
# 0     a       4
# 3     b       3
# 6     c       7

# %%
data= pd.series(1.0987, -999, -1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1e4fa8447cf1> in <module>()
# ----> 1 data= pd.series(1.0987, -999, -1000)
#
# AttributeError: 'module' object has no attribute 'series'

# %%
data = pd.Series(1.0987, -999, -1000)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-7924b58ca55d> in <module>()
# ----> 1 data = pd.Series(1.0987, -999, -1000)
#       2 data
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     135
#     136             if index is not None:
# --> 137                 index = _ensure_index(index)
#     138
#     139             if data is None:
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\indexes\base.py in _ensure_index(index_like, copy)
#    3407             index_like = copy(index_like)
#    3408
# -> 3409     return Index(index_like)
#    3410
#    3411
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     266                          **kwargs)
# ...

# %%
data = pd.Series(1.0987, -999, -1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-23c49874145b> in <module>()
# ----> 1 data = pd.Series(1.0987, -999, -1000)
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     135
#     136             if index is not None:
# --> 137                 index = _ensure_index(index)
#     138
#     139             if data is None:
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\indexes\base.py in _ensure_index(index_like, copy)
#    3407             index_like = copy(index_like)
#    3408
# -> 3409     return Index(index_like)
#    3410
#    3411
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     266                          **kwargs)
# ...

# %%
data = pd.Series([0987., -999., -1000.])
data
# Out:
# 0     987.0
# 1    -999.0
# 2   -1000.0
# dtype: float64

# %%
data.replace(-999, np.nan, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f8fb00a36cfd> in <module>()
# ----> 1 data.replace(-999, np.nan, inplace=True)
#
# NameError: name 'np' is not defined

# %%
data.replace(-999, np.nan, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9680653b6e3f> in <module>()
# ----> 1 data.replace(-999, np.nan, inplace=True)
#       2 data
#
# NameError: name 'np' is not defined

# %%
import numpy as np
data.replace(-999, np.nan, inplace=True)
data
# Out:
# 0     987.0
# 1       NaN
# 2   -1000.0
# dtype: float64

# %%
df= pd.read_csv('C:\Users\Pradnya\Documents\ml-1m\movies.dat')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-34-a29c18c84ef4> in <module>()
# ----> 1 df= pd.read_csv('C:\Users\Pradnya\Documents\ml-1m\movies.dat')
#
# ...

# %%
df= pd.read_csv("C:\Users\Pradnya\Documents\ml-1m\movies.dat")
df
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-35-62c9f41b46cd> in <module>()
# ----> 1 df= pd.read_csv('C:\Users\Pradnya\Documents\ml-1m\movies.dat')
#       2 df
#
# ...

# %%
df= pd.read_csv("C:\Users\Pradnya\Documents\ml-1m\movies.dat")
df
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-36-b980c7da7cbd> in <module>()
# ----> 1 df= pd.read_csv("C:\Users\Pradnya\Documents\ml-1m\movies.dat")
#       2 df
#
# ...

# %%
df= pd.read_csv("C:\Users\Pradnya\Documents\ml-1m\movies.dat")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-37-b0b4a89e89ac> in <module>()
# ----> 1 df= pd.read_csv("C:\Users\Pradnya\Documents\ml-1m\movies.dat")
#
# ...

# %%
loaded=np.loadtext(movies.dat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-2c46dbe8d466> in <module>()
# ----> 1 loaded=np.loadtext(movies.dat)
#
# AttributeError: 'module' object has no attribute 'loadtext'

# %%
loaded=np.loadtxt("movies.dat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-673ea6f5bb91> in <module>()
# ----> 1 loaded=np.loadtxt("movies.dat")
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ValueError: invalid literal for float(): 1::Toy

# %%
import nympy as np
adata1= np.loadtxt("movies.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-40-1511bcd66a08> in <module>()
# ----> 1 import nympy as np
#       2 data1= np.loadtxt("movies.dat")
#       3 data1
#
# ImportError: No module named nympy

# %%
import numpy as np
adata1= np.loadtxt("movies.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-09e9c5440f83> in <module>()
#       1 import numpy as np
# ----> 2 adata1= np.loadtxt("movies.dat")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
data1= np.loadtxt("movies.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-dba51ec5bcdb> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.loadtxt("movies.dat")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
data1= np.loadtxt("README")
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-21c21294b586> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.loadtxt("README")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
data1= np.loadtxt("README.text")
data1
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-44-88fb400af207> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.loadtxt("README.text")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'README.text'

# %%
import numpy as np
data1= np.loadtxt("README")
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-21c21294b586> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.loadtxt("README")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
data1= np.loadtxt("users.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-7998e7e348ca> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.loadtxt("users.dat")
#       3 data1
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
data1= np.read("users.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-18ba44b63729> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.read("users.dat")
#       3 data1
#
# AttributeError: 'module' object has no attribute 'read'

# %%
import numpy as np
data1= pandas.read_csv("users.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-649d643ef4ee> in <module>()
#       1 import numpy as np
# ----> 2 data1= pandas.read_csv("users.dat")
#       3 data1
#
# NameError: name 'pandas' is not defined

# %%
import numpy as np
data1= np.read_csv("users.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-b2b508cfb08c> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.read_csv("users.dat")
#       3 data1
#
# AttributeError: 'module' object has no attribute 'read_csv'

# %%
import numpy as np
data1= np.read_csv("read.txt")
data1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-71bb9d8c35b9> in <module>()
#       1 import numpy as np
# ----> 2 data1= np.read_csv("read.txt")
#       3 data1
#
# AttributeError: 'module' object has no attribute 'read_csv'

# %%
import pandas as pd
data1= pd.read_csv("users.dat")
data1
# Out:
#                1::F::1::10::48067
# 0             2::M::56::16::70072
# 1             3::M::25::15::55117
# 2              4::M::45::7::02460
# 3             5::M::25::20::55455
# 4              6::F::50::9::55117
# 5              7::M::35::1::06810
# 6             8::M::25::12::11413
# 7             9::M::25::17::61614
# 8             10::F::35::1::95370
# 9             11::F::25::1::04093
# 10           12::M::25::12::32793
# 11            13::M::45::1::93304
# 12            14::M::35::0::60126
# 13            15::M::25::7::22903
# 14            16::F::35::0::20670
# 15            17::M::50::1::95350
# 16            18::F::18::3::95825
# 17            19::M::1::10::48073
# 18           20::M::25::14::55113
# 19           21::M::18::16::99353
# 20           22::M::18::15::53706
# 21            23::M::35::0::90049
# 22            24::F::25::7::10023
# 23            25::M::18::4::01609
# 24            26::M::25::7::23112
# 25           27::M::25::11::19130
# ...

# %%
import pandas as pd
data2= pd.read_csv("movies.dat")
data2
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-53-9b3c0a624c08> in <module>()
#       1 import pandas as pd
# ----> 2 data2= pd.read_csv("movies.dat")
#       3 data2
#
# ...

# %%
import pandas as pd
data1= pd.read_csv("ratings.dat")
data1
# Out:
#             1::1193::5::978300760
# 0            1::661::3::978302109
# 1            1::914::3::978301968
# 2           1::3408::4::978300275
# 3           1::2355::5::978824291
# 4           1::1197::3::978302268
# 5           1::1287::5::978302039
# 6           1::2804::5::978300719
# 7            1::594::4::978302268
# 8            1::919::4::978301368
# 9            1::595::5::978824268
# 10           1::938::4::978301752
# 11          1::2398::4::978302281
# 12          1::2918::4::978302124
# 13          1::1035::5::978301753
# 14          1::2791::4::978302188
# 15          1::2687::3::978824268
# 16          1::2018::4::978301777
# 17          1::3105::5::978301713
# 18          1::2797::4::978302039
# 19          1::2321::3::978302205
# 20           1::720::3::978300760
# 21          1::1270::5::978300055
# 22           1::527::5::978824195
# 23          1::2340::3::978300103
# 24            1::48::5::978824351
# 25          1::1097::4::978301953
# ...

# %%
import pandas as pd
data1= pd.read_csv("README.text")
data1
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-57-aabc5ba7cc16> in <module>()
#       1 import pandas as pd
# ----> 2 data1= pd.read_csv("README.text")
#       3 data1
#
# ...

# %%
import pandas as pd
data1= pd.read_csv("movies.dat")
data1
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-56-412080e453d0> in <module>()
#       1 import pandas as pd
# ----> 2 data1= pd.read_csv("movies.dat")
#       3 data1
#
# ...
